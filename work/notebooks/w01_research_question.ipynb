# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I selected Lane 2: Refresh / Content Opportunity Scoring.
#
# I selected this lane because it focuses on identifying which content pages should be reviewed first based on observable search and engagement signals.
#
# Machine learning can help prioritize pages by finding patterns in historical performance data and generating evidence-based recommendations.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision:
# Which content pages should be prioritized for review and possible improvement?
#
# Action:
# The output can help content teams decide which pages need refresh, expansion, monitoring, or further investigation.
#
# Cost of a wrong call:
# A wrong recommendation may waste optimization resources on pages that do not need changes or may cause important pages to be ignored.
#
# Research Question:
# Can machine learning identify content pages that are most likely to need attention based on available search and engagement signals?

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains:
#
# - [rows number] content records.
# - [columns number] features.
# - The dataset includes observable content performance signals such as impressions, clicks, sessions, and engagement metrics.
#
# These signals make this lane suitable because they provide measurable evidence for prioritizing content review decisions.

# %%
 # !git clone  https://github.com/wajiha442/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
 import os
os.listdir()
# Out:
# ['.config', 'flyrank-ml-internship', 'sample_data']

# %%
 # !find flyrank-ml-internship -name "content_refresh_anonymized.csv"
# Out:
# flyrank-ml-internship/data/raw/content_refresh_anonymized.csv

# %%
 import pandas as pd

df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

df.shape
# Out:
# (30000, 44)

# %%
df.shape
# Out:
# (30000, 44)

# %%
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can investigate whether machine learning can identify patterns associated with content performance and prioritize pages for review.
#
# I cannot claim that the model will guarantee a page improvement or prove that a specific action will cause recovery.
#
# The goal is decision support, not replacing human judgement.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
